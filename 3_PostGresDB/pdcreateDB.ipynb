# %%
import pandas as pd

# %%
import glob
path_8 = "/home/alem/Desktop/SummerProject/0_finalJan22_2021/DashProject02June20/DatasetsAndReprots/checklist/"
chklstpath = glob.glob(path_8+'*.xlsx')
chklstpath= chklstpath[0].replace(path_8, '')

# %%
lstr = ['P',' ', 'F']
'P' in lstr or 'F' in lstr
# Out:
# True

# %%
chklstpath
# Out:
# 'check_list_2020.xlsx'

# %%
t1 =pd.read_csv('./dset/aapl.csv')
t2 =pd.read_excel('./dset/new.xlsx')
t3 = pd.read_csv('./dset/OfficeSupplies.csv')
t4 = pd.read_excel('./dset/stocks.xlsx')
t5 = pd.read_csv('./dset/wmt.csv')

# %%
import sqlalchemy  # Package for accessing SQL databases via Python

# Connect to database (Note: The package psychopg2 is required for Postgres to work with SQLAlchemy)
engine = sqlalchemy.create_engine("postgresql://alem@localhost/mydb")
con = engine.connect()
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# ~/anaconda3/lib/python3.7/site-packages/sqlalchemy/engine/base.py in _wrap_pool_connect(self, fn, connection)
#    2274         try:
# -> 2275             return fn()
#    2276         except dialect.dbapi.Error as e:
#
# ~/anaconda3/lib/python3.7/site-packages/sqlalchemy/pool/base.py in unique_connection(self)
#     302         """
# --> 303         return _ConnectionFairy._checkout(self)
#     304
#
# ~/anaconda3/lib/python3.7/site-packages/sqlalchemy/pool/base.py in _checkout(cls, pool, threadconns, fairy)
#     759         if not fairy:
# --> 760             fairy = _ConnectionRecord.checkout(pool)
#     761
#
# ~/anaconda3/lib/python3.7/site-packages/sqlalchemy/pool/base.py in checkout(cls, pool)
#     491     def checkout(cls, pool):
# --> 492         rec = pool._do_get()
#     493         try:
#
# ...

# %%
# Verify that there are no existing tables
print(engine.table_names())
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# ~/anaconda3/lib/python3.7/site-packages/sqlalchemy/engine/base.py in _wrap_pool_connect(self, fn, connection)
#    2274         try:
# -> 2275             return fn()
#    2276         except dialect.dbapi.Error as e:
#
# ~/anaconda3/lib/python3.7/site-packages/sqlalchemy/pool/base.py in unique_connection(self)
#     302         """
# --> 303         return _ConnectionFairy._checkout(self)
#     304
#
# ~/anaconda3/lib/python3.7/site-packages/sqlalchemy/pool/base.py in _checkout(cls, pool, threadconns, fairy)
#     759         if not fairy:
# --> 760             fairy = _ConnectionRecord.checkout(pool)
#     761
#
# ~/anaconda3/lib/python3.7/site-packages/sqlalchemy/pool/base.py in checkout(cls, pool)
#     491     def checkout(cls, pool):
# --> 492         rec = pool._do_get()
#     493         try:
#
# ...

# %%
engine = create_engine("sqlite://mydatabase.db", echo=False)

for each_item in items:
    connection = engine.connect()
    pandas.DataFrame.to_sql(my_function(each_item), name=each_item, con=engine, if_exists="replace")
    connection.close()
    print(each_item + " has been completed successfully.")
print("All completed.")
# Out:
# ---------------------------------------------------------------------------
# ArgumentError                             Traceback (most recent call last)
# <ipython-input-21-a2972b884fba> in <module>
# ----> 1 engine = create_engine("sqlite://mydatabase.db", echo=False)
#       2
#       3 for each_item in items:
#       4     connection = engine.connect()
#       5     pandas.DataFrame.to_sql(my_function(each_item), name=each_item, con=engine, if_exists="replace")
#
# ~/anaconda3/lib/python3.7/site-packages/sqlalchemy/engine/__init__.py in create_engine(*args, **kwargs)
#     477     strategy = kwargs.pop("strategy", default_strategy)
#     478     strategy = strategies.strategies[strategy]
# --> 479     return strategy.create(*args, **kwargs)
#     480
#     481
#
# ~/anaconda3/lib/python3.7/site-packages/sqlalchemy/engine/strategies.py in create(self, name_or_url, **kwargs)
#      96
#      97         # assemble connection arguments
# ...

# %%
import sqlite3
#Create a connection
conn = sqlite3.connect("sqlite://mydatabase.db")
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# <ipython-input-20-cbb1fd99e056> in <module>
#       1 import sqlite3
#       2 #Create a connection
# ----> 3 conn = sqlite3.connect("sqlite:///mydatabase.db")
#
# OperationalError: unable to open database file

# %%
db1 = pd.read_sql("sqlite:///mydatabase.db")
